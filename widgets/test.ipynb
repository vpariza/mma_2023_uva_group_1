# %%
import ini
from utils import file_utils

# %%
df = file_utils.load_from_pickle('../data.pkl')

# %%
df
# Out:
#      funda_identifier                location_part1       location_part2  \
# 0            42126054                    Hogeweg 66   3814 CE Amersfoort
# 1            42126250                     Olivijn 8        5912 PV Venlo
# 2            42189920                  Dwarslaan 10     1261 BB Blaricum
# 3            42115579             Vuurdoornstraat 1         6101 MB Echt
# 4            42106112               Van Lennephof 1          5343 JC Oss
# ...               ...                           ...                  ...
# 1449         42119201     Tussenwoning (Bouwnr. 28)      1474 Oosthuizen
# 1450         42102500                  Zandkamp 156     3828 GK Hoogland
# 1451         42109353  Generaal De la Reijstraat 15      2021 XR Haarlem
# 1452         42129995              Schipperslaan 11    1442 AB Purmerend
# 1453         42100243                Vredenseweg 26  7101 LP Winterswijk
#
#              location_part3    price  living_area bedrooms  \
# ...

# %%
df.keys()
# Out:
# Index(['funda_identifier', 'location_part1', 'location_part2',
#        'location_part3', 'price', 'living_area', 'bedrooms',
#        'asking_price_per_m²', 'listed_since', 'status', 'acceptance',
#        'building_type', 'year_of_construction', 'volume_in_cubic_meters',
#        'number_of_rooms', 'number_of_bath_rooms', 'bathroom_facilities',
#        'number_of_stories', 'facilities', 'label', 'insulation', 'heating',
#        'hot_water', 'garden', 'type_of_facilities', 'lat', 'lon',
#        'description', 'images_paths', 'in_the_neighborhood', 'type_of_roof',
#        'location', 'coords'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(42)
x = np.random.normal(size=1000)

def plot_feature(data, bins=30):
    plt.hist(data, density=False, bins=min(30, bins))  # density=False would make counts
    plt.ylabel('Counts')
    plt.xlabel('Data')
    plt.xticks(rotation=90)
    plt.show()

# %%
from enum import Enum
class HouseInfoDistKeys(Enum):
    LONGITUDE = 'lon'
    LATITUDE = 'lat'
    POINT_COORDS = 'coords'
    LISTING_ID = 'funda_identifier'
    @classmethod
    def list(cls):
        return list(map(lambda c: c.value, cls))

# %%
HouseInfoDistKeys.list()
# Out:
# ['lon', 'lat', 'coords', 'funda_identifier']

# %%
import ini
from utils.file_utils import load_from_pickle
df = load_from_pickle('../data.pkl')

# %%
df.keys()
# Out:
# Index(['funda_identifier', 'location_part1', 'location_part2',
#        'location_part3', 'price', 'living_area', 'bedrooms',
#        'asking_price_per_m²', 'listed_since', 'status', 'acceptance',
#        'building_type', 'year_of_construction', 'volume_in_cubic_meters',
#        'number_of_rooms', 'number_of_bath_rooms', 'bathroom_facilities',
#        'number_of_stories', 'facilities', 'label', 'insulation', 'heating',
#        'hot_water', 'garden', 'type_of_facilities', 'lat', 'lon',
#        'description', 'images_paths', 'in_the_neighborhood', 'type_of_roof',
#        'location', 'coords'],
#       dtype='object')

# %%
from enum import Enum
class HouseInfoDistKeys(Enum):
    LONGITUDE = 'lon'
    LATITUDE = 'lat'
    LISTING_ID = 'funda_identifier'
    PRICE = 'price'
    LIVING_AREA = 'living_area'
    BEDROOMS = 'bedrooms'
    ASK_PRICE_PER_SQ_M = 'asking_price_per_m²'
    STATUS = 'status'
    ACCEPTANCE = 'acceptance'
    BUILDING_TYPE = 'building_type'
    NUM_BATH_ROOMS = 'number_of_bath_rooms'
    LABEL = 'label'
    HEATING = 'heating'
    GARDEN = 'garden'
    FACILITIES_TYPE = 'type_of_facilities'
    NEIGHBERHOOD = 'in_the_neighborhood'

    @classmethod
    def list_values(cls):
        return list(map(lambda c: c.value, cls))

# %%
for item_name in HouseInfoDistKeys.list_values():
    try:
        plot_feature(df[item_name], bins=len(set(df[item_name].values.tolist())))
        print('It worked',item_name)
    except:
        print('Did not work',item_name)
# Out:
# It worked lon
# It worked lat
# It worked funda_identifier
# It worked price
# It worked living_area
# It worked bedrooms
# It worked asking_price_per_m²
# It worked status
# It worked acceptance
# It worked building_type
# It worked number_of_bath_rooms
# It worked label
# It worked heating
# It worked garden
# It worked type_of_facilities
# Did not work in_the_neighborhood

# %%
from sklearn.preprocessing import minmax_scale

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'a':np.arange(10),
    'b':np.arange(10)*2,
    'c':np.arange(10)*2,
}

# %%
list(pd.DataFrame(data).keys())
# Out:
# ['a', 'b', 'c']
