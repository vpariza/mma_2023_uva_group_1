# %%
import ini
from utils import file_utils

# %%
df = file_utils.load_from_pickle('../data.pkl')

# %%
df
# Out:
#      funda_identifier                location_part1       location_part2
# 0            42126054                    Hogeweg 66   3814 CE Amersfoort  \
# 1            42126250                     Olivijn 8        5912 PV Venlo
# 2            42189920                  Dwarslaan 10     1261 BB Blaricum
# 3            42115579             Vuurdoornstraat 1         6101 MB Echt
# 4            42106112               Van Lennephof 1          5343 JC Oss
# ...               ...                           ...                  ...
# 1449         42119201     Tussenwoning (Bouwnr. 28)      1474 Oosthuizen
# 1450         42102500                  Zandkamp 156     3828 GK Hoogland
# 1451         42109353  Generaal De la Reijstraat 15      2021 XR Haarlem
# 1452         42129995              Schipperslaan 11    1442 AB Purmerend
# 1453         42100243                Vredenseweg 26  7101 LP Winterswijk
#
#              location_part3    price  living_area bedrooms
# 0            Kruiskamp-Zuid   450000          110        2  \
# 1                Hagerbroek   498000          160        4
# 2             Blaricum-Dorp  1750000          206        3
# 3                Echt Noord   399000          157        4
# 4           Vondellaan-Zuid   300000          124        4
# ...                     ...      ...          ...      ...
# 1449            De Watering   395000          113        3
# 1450         Bieshaar-Noord   369500          122        4
# 1451         Generaalsbuurt   675000          149        4
# 1452         Overwhere-Zuid   925000          161        4
# 1453  Winterswijk-Noordoost   199500           96        2
#
#       asking_price_per_m²  listed_since        status  ...
# 0                   4.091         Today     Available  ...  \
# 1                   3.112         Today     Available  ...
# 2                   8.495  May 12, 2023     Available  ...
# 3                   2.541  May 14, 2023     Available  ...
# 4                   2.419   May 8, 2023  Under option  ...
# ...                   ...           ...           ...  ...
# 1449                3.496         Today     Available  ...
# 1450                3.029  May 11, 2023     Available  ...
# 1451                4.530  May 11, 2023     Available  ...
# 1452                5.745  May 26, 2023     Available  ...
# 1453                2.078  May 10, 2023   Under offer  ...
#
#                                                  garden
# 0                          Back garden and front garden  \
# 1             Back garden, front garden and side garden
# 2     Back garden, surrounded by garden, front garde...
# 3                          Back garden and front garden
# 4                          Back garden and front garden
# ...                                                 ...
# 1449                       Back garden and front garden
# 1450                       Back garden and front garden
# 1451
# 1452                               Surrounded by garden
# 1453                                        Back garden
#
#                                   type_of_facilities       lat       lon
# 0                                     Public parking  52.15718  5.400165  \
# 1                                                     51.35439  6.172892
# 2                                     Public parking  52.27979  5.239072
# 3                        Parking on private property  51.11259  5.875482
# 4     Parking on private property and public parking  51.74699  5.510582
# ...                                              ...       ...       ...
# 1449                                  Public parking  52.56520  4.994301
# 1450  Parking on private property and public parking  52.19217  5.370471
# 1451                                    Paid parking  52.39311  4.642666
# 1452  Parking on private property and public parking  52.51184  4.949470
# 1453  Parking on private property and public parking  51.97467  6.728329
#
#                                             description
# 0     This charming and well-maintained single-famil...  \
# 1     Olivine 8, 5912 PV Venlo. This spacious, detac...
# 2     In one of the most beautiful locations of Blar...
# 3     DUE TO THE GREAT INTEREST IN THIS PROPERTY IT ...
# 4     A house to make a fresh start For Saskia it is...
# ...                                                 ...
# 1449  In Waterrijk phase 3B there will be a total of...
# 1450  NEW ON SALE: INTERMEDIATE HOUSE WITH 4 BEDROOM...
# 1451  PUUR* living in this terraced house (living ar...
# 1452  Beautiful detached villa for sale near the old...
# 1453  LOCATED ON THE EDGE OF THE CENTER 2/1 DETACHED...
#
#                                            images_paths
# 0     [42126054/image3.jpeg, 42126054/image1.jpeg, 4...  \
# 1     [42126250/image3.jpeg, 42126250/image1.jpeg, 4...
# 2     [42189920/image3.jpeg, 42189920/image1.jpeg, 4...
# 3     [42115579/image3.jpeg, 42115579/image1.jpeg, 4...
# 4     [42106112/image3.jpeg, 42106112/image1.jpeg, 4...
# ...                                                 ...
# 1449  [42119201/image3.jpeg, 42119201/image1.jpeg, 4...
# 1450  [42102500/image3.jpeg, 42102500/image1.jpeg, 4...
# 1451  [42109353/image3.jpeg, 42109353/image1.jpeg, 4...
# 1452  [42129995/image3.jpeg, 42129995/image1.jpeg, 4...
# 1453  [42100243/image3.jpeg, 42100243/image1.jpeg, 4...
#
#                              in_the_neighborhood
# 0     [Elementary school, Supermarket, Bus stop]  \
# 1     [Elementary school, Supermarket, Bus stop]
# 2     [Elementary school, Supermarket, Bus stop]
# 3     [Elementary school, Supermarket, Bus stop]
# 4     [Elementary school, Supermarket, Bus stop]
# ...                                          ...
# 1449  [Elementary school, Supermarket, Bus stop]
# 1450  [Elementary school, Supermarket, Bus stop]
# 1451  [Elementary school, Supermarket, Bus stop]
# 1452  [Elementary school, Supermarket, Bus stop]
# 1453  [Elementary school, Supermarket, Bus stop]
#
#                                 type_of_roof
# 0                                             \
# 1                                  Flat roof
# 2         Gable roof covered with roof tiles
# 3         Gable roof covered with roof tiles
# 4         Gable roof covered with roof tiles
# ...                                      ...
# 1449      Gable roof covered with roof tiles
# 1450  Flat roof covered with asphalt roofing
# 1451                        Combination roof
# 1452  Flat roof covered with asphalt roofing
# 1453      Gable roof covered with roof tiles
#
#                                                location
# 0                                                        \
# 1     Alongside a quiet road and in residential dist...
# 2     Alongside a quiet road and In wooded surroundings
# 3     Alongside a quiet road, In wooded surroundings...
# 4
# ...                                                 ...
# 1449                          Outside the built-up area
# 1450                            In residential district
# 1451  Alongside a quiet road and in residential dist...
# 1452                            In residential district
# 1453
#
#                          coords
# 0     POINT (52.15718 5.400165)
# 1     POINT (51.35439 6.172892)
# 2     POINT (52.27979 5.239072)
# 3     POINT (51.11259 5.875482)
# 4     POINT (51.74699 5.510582)
# ...                         ...
# 1449   POINT (52.5652 4.994301)
# 1450  POINT (52.19217 5.370471)
# 1451  POINT (52.39311 4.642666)
# 1452   POINT (52.51184 4.94947)
# 1453  POINT (51.97467 6.728329)
#
# [1444 rows x 33 columns]

# %%
df.keys()
# Out:
# Index(['funda_identifier', 'location_part1', 'location_part2',
#        'location_part3', 'price', 'living_area', 'bedrooms',
#        'asking_price_per_m²', 'listed_since', 'status', 'acceptance',
#        'building_type', 'year_of_construction', 'volume_in_cubic_meters',
#        'number_of_rooms', 'number_of_bath_rooms', 'bathroom_facilities',
#        'number_of_stories', 'facilities', 'label', 'insulation', 'heating',
#        'hot_water', 'garden', 'type_of_facilities', 'lat', 'lon',
#        'description', 'images_paths', 'in_the_neighborhood', 'type_of_roof',
#        'location', 'coords'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(42)
x = np.random.normal(size=1000)

def plot_feature()
plt.hist(df['price'], density=False, bins=30)  # density=False would make counts
plt.ylabel('Counts')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
from enum import Enum
class HouseInfoDistKeys(Enum):
    LONGITUDE = 'lon'
    LATITUDE = 'lat'
    POINT_COORDS = 'coords'
    LISTING_ID = 'funda_identifier'
    @classmethod
    def list(cls):
        return list(map(lambda c: c.value, cls))

# %%
HouseInfoDistKeys.list()
# Out:
# ['lon', 'lat', 'coords', 'funda_identifier']
